# %% [raw]
# # Aim :
# ## Predicting Stock prices of Apple
# Our first aim is to predict the next day closing stock price for Microsoft, Google and Amazon. **For this we will train the model that learns from the data of all the 3 companies.**
# ## Transfer Learning : Experment with transfer learning of different combinations of companies

# %% [markdown]
# # Dataset : [NYSE Kaggle]

# %%
import numpy as np
import pandas
import seaborn
import matplotlib.pyplot as plt

# %%
dfm = pandas.read_csv('MSFT.csv')
dfm["symbol"]= "MSFT"

# %%
dfg = pandas.read_csv('GOOGL.csv')
dfg["symbol"]= "GOOGL"

# %%
dfa = pandas.read_csv('AMZN.csv')
dfa["symbol"]= "AMZN"

# %%
frames = [dfm,dfg,dfa]

# %%
#result = pandas.merge(dfm,dfa, on = ["Date"])
#result = pandas.merge(result,dfg,left_index=True, right_index=True)
#result

# %%
dfa.shape
# Out:
# (1259, 8)

# %%
#import functools as ft
#df_final = ft.reduce(lambda left, right: pandas.merge(left, right, on='Date'), frames)

# %%
main_df = pandas.concat(frames)

# %%
main_df.sort_values(by='Date')
#main_df.sort(['Date','Close']).groupby('Date')['status'].last()
print(main_df)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2017-11-27  83.309998  83.980003  83.300003  83.870003  78.981628
# 1     2017-11-28  84.070000  85.059998  84.019997  84.879997  79.932755
# 2     2017-11-29  84.709999  84.919998  83.180000  83.339996  78.482498
# 3     2017-11-30  83.510002  84.519997  83.339996  84.169998  79.264137
# 4     2017-12-01  83.599998  84.809998  83.220001  84.260002  79.348877
# ...          ...        ...        ...        ...        ...        ...
# 1254  2022-11-18  95.949997  95.989998  92.480003  94.139999  94.139999
# 1255  2022-11-21  93.970001  95.019997  90.589996  92.459999  92.459999
# 1256  2022-11-22  92.620003  93.349998  90.870003  93.199997  93.199997
# 1257  2022-11-23  93.239998  94.580002  92.830002  94.129997  94.129997
# 1258  2022-11-25  93.790001  94.430000  93.070000  93.410004  93.410004
#
#         Volume symbol
# 0     18265200   MSFT
# 1     21926000   MSFT
# 2     27381100   MSFT
# 3     33054600   MSFT
# 4     29532100   MSFT
# ...        ...    ...
# 1254  72336500   AMZN
# 1255  84330300   AMZN
# 1256  62192000   AMZN
# 1257  59414700   AMZN
# 1258  35088600   AMZN
#
# [3777 rows x 8 columns]

# %%
main_df.groupby(['Date'])

# %%
main_df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2017-11-27  83.309998  83.980003  83.300003  83.870003  78.981628
# 1     2017-11-28  84.070000  85.059998  84.019997  84.879997  79.932755
# 2     2017-11-29  84.709999  84.919998  83.180000  83.339996  78.482498
# 3     2017-11-30  83.510002  84.519997  83.339996  84.169998  79.264137
# 4     2017-12-01  83.599998  84.809998  83.220001  84.260002  79.348877
# ...          ...        ...        ...        ...        ...        ...
# 1254  2022-11-18  95.949997  95.989998  92.480003  94.139999  94.139999
# 1255  2022-11-21  93.970001  95.019997  90.589996  92.459999  92.459999
# 1256  2022-11-22  92.620003  93.349998  90.870003  93.199997  93.199997
# 1257  2022-11-23  93.239998  94.580002  92.830002  94.129997  94.129997
# 1258  2022-11-25  93.790001  94.430000  93.070000  93.410004  93.410004
#
#         Volume symbol
# 0     18265200   MSFT
# 1     21926000   MSFT
# 2     27381100   MSFT
# 3     33054600   MSFT
# 4     29532100   MSFT
# ...        ...    ...
# 1254  72336500   AMZN
# 1255  84330300   AMZN
# 1256  62192000   AMZN
# 1257  59414700   AMZN
# 1258  35088600   AMZN
#
# [3777 rows x 8 columns]

# %%
#dfs = [main_df.set_index(['Date']) for df in [dfa, dfm, dfg]]

#print(pandas.concat(dfs, axis=1).reset_index())

# %%
main_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-27  83.309998  83.980003  83.300003  83.870003  78.981628
# 1  2017-11-28  84.070000  85.059998  84.019997  84.879997  79.932755
# 2  2017-11-29  84.709999  84.919998  83.180000  83.339996  78.482498
# 3  2017-11-30  83.510002  84.519997  83.339996  84.169998  79.264137
# 4  2017-12-01  83.599998  84.809998  83.220001  84.260002  79.348877
#
#      Volume symbol
# 0  18265200   MSFT
# 1  21926000   MSFT
# 2  27381100   MSFT
# 3  33054600   MSFT
# 4  29532100   MSFT

# %%
main_df.tail()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1254  2022-11-18  95.949997  95.989998  92.480003  94.139999  94.139999
# 1255  2022-11-21  93.970001  95.019997  90.589996  92.459999  92.459999
# 1256  2022-11-22  92.620003  93.349998  90.870003  93.199997  93.199997
# 1257  2022-11-23  93.239998  94.580002  92.830002  94.129997  94.129997
# 1258  2022-11-25  93.790001  94.430000  93.070000  93.410004  93.410004
#
#         Volume symbol
# 1254  72336500   AMZN
# 1255  84330300   AMZN
# 1256  62192000   AMZN
# 1257  59414700   AMZN
# 1258  35088600   AMZN

# %%
print(main_df['Date'].min())
print(main_df['Date'].max())
# Out:
# 2017-11-27
# 2022-11-25

# %% [markdown]
# # Filtering out the dataset
# Our aim will be limited to predicting **Apple, Google and Amazon stocks**. Ticker symbol for the respective companies are AAPL, GOOGL and AMZN.

# %%
print(dfm[dfm['symbol'] == 'MSFT'].shape)
print(dfg[dfg['symbol'] =='GOOGL'].shape)
print(dfa[dfa['symbol'] == 'AMZN'].shape)
# Out:
# (1259, 8)
# (1259, 8)
# (1259, 8)

# %%
main_df = main_df[(main_df['symbol'] == 'MSFT') | (main_df['symbol'] == 'GOOGL') | (main_df['symbol'] == 'AMZN')].reset_index(drop = True)

# %%
main_df = main_df.drop(['Adj Close'], axis = 1)

# %%
print('Number of missing values : ' + str(main_df.isna().sum().sum()))
# Out:
# Number of missing values : 0

# %%
main_df.head(9)
# Out:
#          Date       Open       High        Low      Close    Volume symbol
# 0  2017-11-27  83.309998  83.980003  83.300003  83.870003  18265200   MSFT
# 1  2017-11-28  84.070000  85.059998  84.019997  84.879997  21926000   MSFT
# 2  2017-11-29  84.709999  84.919998  83.180000  83.339996  27381100   MSFT
# 3  2017-11-30  83.510002  84.519997  83.339996  84.169998  33054600   MSFT
# 4  2017-12-01  83.599998  84.809998  83.220001  84.260002  29532100   MSFT
# 5  2017-12-04  84.419998  84.430000  80.699997  81.080002  39094900   MSFT
# 6  2017-12-05  81.339996  82.680000  80.980003  81.589996  26152300   MSFT
# 7  2017-12-06  81.550003  83.139999  81.430000  82.779999  26162100   MSFT
# 8  2017-12-07  82.540001  82.800003  82.000000  82.489998  23184500   MSFT

# %% [markdown]
# # Starting and ending duration

# %%
print(main_df['Date'].min())
print(main_df['Date'].max())
# Out:
# 2017-11-27
# 2022-11-25

# %% [markdown]
# So we have data from **4th of January, 2010** to **30th of December, 2016**

# %% [markdown]
# # One hot encode the symbols

# %%
main_df = pandas.get_dummies(main_df, columns = ['symbol'])

# %%
main_df.head(9)
# Out:
#          Date       Open       High        Low      Close    Volume  \
# 0  2017-11-27  83.309998  83.980003  83.300003  83.870003  18265200
# 1  2017-11-28  84.070000  85.059998  84.019997  84.879997  21926000
# 2  2017-11-29  84.709999  84.919998  83.180000  83.339996  27381100
# 3  2017-11-30  83.510002  84.519997  83.339996  84.169998  33054600
# 4  2017-12-01  83.599998  84.809998  83.220001  84.260002  29532100
# 5  2017-12-04  84.419998  84.430000  80.699997  81.080002  39094900
# 6  2017-12-05  81.339996  82.680000  80.980003  81.589996  26152300
# 7  2017-12-06  81.550003  83.139999  81.430000  82.779999  26162100
# 8  2017-12-07  82.540001  82.800003  82.000000  82.489998  23184500
#
#    symbol_AMZN  symbol_GOOGL  symbol_MSFT
# 0            0             0            1
# 1            0             0            1
# 2            0             0            1
# 3            0             0            1
# 4            0             0            1
# 5            0             0            1
# 6            0             0            1
# 7            0             0            1
# 8            0             0            1

# %%
from tabulate import tabulate
info = [[col, main_df[col].count(), main_df[col].max(), main_df[col].min()] for col in main_df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt= 'orgtbl'))
# Out:
# | Feature      |   Count | Maximum    | Minimum    |
# |--------------+---------+------------+------------|
# | Date         |    3777 | 2022-11-25 | 2017-11-27 |
# | Open         |    3777 | 344.619995 | 49.216     |
# | High         |    3777 | 349.670013 | 50.605999  |
# | Low          |    3777 | 342.200012 | 48.882999  |
# | Close        |    3777 | 343.109985 | 49.233501  |
# | Volume       |    3777 | 311346000  | 8989200    |
# | symbol_AMZN  |    3777 | 1          | 0          |
# | symbol_GOOGL |    3777 | 1          | 0          |
# | symbol_MSFT  |    3777 | 1          | 0          |

# %% [markdown]
# # Exploratory Data Analysis

# %%
main_df = main_df.drop(['Date'], axis = 1)

# %%
seaborn.pairplot(main_df.drop(['symbol_MSFT', 'symbol_AMZN', 'symbol_GOOGL'], axis = 1))

# %%
plt.figure(figsize = (15,15))
mat = main_df.drop(['symbol_MSFT', 'symbol_AMZN', 'symbol_GOOGL'], axis = 1).corr()
seaborn.heatmap(mat, annot = True, square = True)

# %%
info = ['Open', 'Close', 'Low', 'High', 'Volume']

# %%
plt.figure(figsize = (20,10))

for i in range(4) :
    plt.subplot(2,2,i+1)
    
    plt.plot(main_df[main_df['symbol_MSFT'] == 1][info[i]].values)
    plt.plot(main_df[main_df['symbol_GOOGL']== 1][info[i]].values)
    plt.plot(main_df[main_df['symbol_AMZN'] == 1][info[i]].values)
    plt.xlabel('time' )
    plt.ylabel(info[i])
    plt.legend(['Microsoft', 'Google', 'Amazon'])
    plt.title(info[i] + ' vs time')
plt.show()

# %% [markdown]
# Since open price, low price, and high price are linearly correlated with closing price, only one of them will be selected to feed the model, to avoid overfitting. And the second feature will be **volume traded**.

# %%
info = [[col, main_df[col].count(), main_df[col].max(), main_df[col].min()] for col in main_df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt = 'orgtbl'))
# Out:
# | Feature      |   Count |       Maximum |     Minimum |
# |--------------+---------+---------------+-------------|
# | Open         |    3777 | 344.62        | 49.216      |
# | High         |    3777 | 349.67        | 50.606      |
# | Low          |    3777 | 342.2         | 48.883      |
# | Close        |    3777 | 343.11        | 49.2335     |
# | Volume       |    3777 |   3.11346e+08 |  8.9892e+06 |
# | symbol_AMZN  |    3777 |   1           |  0          |
# | symbol_GOOGL |    3777 |   1           |  0          |
# | symbol_MSFT  |    3777 |   1           |  0          |

# %%
main_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'symbol_AMZN', 'symbol_GOOGL',
#        'symbol_MSFT'],
#       dtype='object')

# %% [markdown]
# # Create the dataset
# We will use past 300 days data to predict future stock prices, 100 days of stock data for each company. We will use three fields, apart from **opening price and volume traded** to symbolize the company to which the data belongs to.

# %%
X = np.array(main_df.drop(['Close','Low', 'High'], axis = 1))
y = np.array(main_df['Close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (3777, 5)
# (3777,)

# %% [markdown]
# # Scaling the columns

# %%
print(X[:3])
# Out:
# [[8.3309998e+01 1.8265200e+07 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [8.4070000e+01 2.1926000e+07 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [8.4709999e+01 2.7381100e+07 0.0000000e+00 0.0000000e+00 1.0000000e+00]]

# %%
from sklearn.preprocessing import MinMaxScaler
X = MinMaxScaler().fit_transform(X)

# %%
print(X[:3])
# Out:
# [[0.11541482 0.03067899 0.         0.         1.        ]
#  [0.11798757 0.04278654 0.         0.         1.        ]
#  [0.12015409 0.06082846 0.         0.         1.        ]]

# %%
print(y.min())
print(y.max())
# Out:
# 49.233501
# 343.109985

# %%
temp = MinMaxScaler().fit_transform(np.reshape(y, (len(y),1)))
y = temp.reshape(-1)

# %%
print(y.min())
print(y.max())
# Out:
# 0.0
# 1.0

# %%
print(X.min())
print(X.max())
# Out:
# 0.0
# 1.0

# %%
print(y[3:6])
# Out:
# [0.11888157 0.11918783 0.10836696]

# %% [markdown]
# # Creating the actual time series based numpy array
# An **important** point to note is that we will have three outputs or target labels in y. These are the three closing prices, each for AAPL, AMAZN and GOOGL respectively.

# %%
length = 300                         # 100 days * 3 companies

X_res = []
y_res = []

for i in range(length,len(X)-2) :
    X_res.append(X[i-length:i])      # contains features for past 100 days for 3 companies.
    y_res.append(y[i:i+3])           # the next three closing prices for AAPL, AMZN, GOOGL.

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (3475, 300, 5)
# (3475, 3)

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test  = train_test_split(X_res, y_res, test_size = 0.3, shuffle = True, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2432, 300, 5)
# (2432, 3)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (1043, 300, 5)
# (1043, 3)

# %% [markdown]
# # Model creation
# ### Recurrent Neural Network
# Vanilla neural networks do not have a memory and so they do not take into account any past event for predictions. But this kind of model is poor when working with time series data, where there is dependency accross time. This is where RNN come in. A RNN model has **memory**, which can help in retaining past data and so the predictions are made on those basis.
#
# ### Long Short Term Memory
# RNNs have a **short term memory** and are not able to retain dependencies that occured long before the current state. So LSTM or **long short term memory** is used to retain those dependencies as well, using something called gated units.

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization

from keras.layers import Input

# %%
def lstm_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Bidirectional(LSTM(hiddenx, activation = 'tanh', return_sequences = True)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    return model

# %%
def rnn (hidden1, hidden2, hidden3) :
    
    model = Sequential()
    
    # Input Block
    model.add(Input((length, 5,)))
    
    # LSTM Block
    model.add(lstm_layer(hidden1))
    model.add(lstm_layer(hidden2))
    model.add(Bidirectional(LSTM(hidden3, activation = 'tanh', return_sequences = False)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    # Output Block
    model.add(Dense(3, activation = 'linear'))
    
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')
    return model

# %%
model = rnn(128, 128, 32)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_4 (Sequential)   (None, 300, 256)          138240
#
#  sequential_5 (Sequential)   (None, 300, 256)          395264
#
#  bidirectional_5 (Bidirectio  (None, 64)               73984
#  nal)
#
#  batch_normalization_5 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 607,939
# Trainable params: 606,787
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./result_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %%
import tensorflow as tf

# %%
history = model.fit(X_train, y_train, epochs = 10, batch_size = 32, validation_data = (X_test, y_test), callbacks = [checkp])
#history = model.add(tf.keras.layers.Dense(256, input_shape=(X_test.shape[1],), activation='sigmoid'))
# Out:
# Epoch 1/10
# 76/76 [==============================] - ETA: 0s - loss: 0.6088
# Epoch 1: val_loss improved from inf to 0.09761, saving model to ./result_model.h5
# 76/76 [==============================] - 213s 3s/step - loss: 0.6088 - val_loss: 0.0976
# Epoch 2/10
# 76/76 [==============================] - ETA: 0s - loss: 0.3657
# Epoch 2: val_loss improved from 0.09761 to 0.06504, saving model to ./result_model.h5
# 76/76 [==============================] - 193s 3s/step - loss: 0.3657 - val_loss: 0.0650
# Epoch 3/10
# 76/76 [==============================] - ETA: 0s - loss: 0.2805
# Epoch 3: val_loss improved from 0.06504 to 0.05110, saving model to ./result_model.h5
# 76/76 [==============================] - 196s 3s/step - loss: 0.2805 - val_loss: 0.0511
# Epoch 4/10
# 76/76 [==============================] - ETA: 0s - loss: 0.2155
# Epoch 4: val_loss improved from 0.05110 to 0.02129, saving model to ./result_model.h5
# 76/76 [==============================] - 222s 3s/step - loss: 0.2155 - val_loss: 0.0213
# Epoch 5/10
# 76/76 [==============================] - ETA: 0s - loss: 0.1613
# Epoch 5: val_loss did not improve from 0.02129
# 76/76 [==============================] - 215s 3s/step - loss: 0.1613 - val_loss: 0.0256
# Epoch 6/10
# 76/76 [==============================] - ETA: 0s - loss: 0.1331
# Epoch 6: val_loss improved from 0.02129 to 0.00722, saving model to ./result_model.h5
# 76/76 [==============================] - 211s 3s/step - loss: 0.1331 - val_loss: 0.0072
# Epoch 7/10
# 76/76 [==============================] - ETA: 0s - loss: 0.0993
# Epoch 7: val_loss did not improve from 0.00722
# 76/76 [==============================] - 215s 3s/step - loss: 0.0993 - val_loss: 0.0088
# Epoch 8/10
# 76/76 [==============================] - ETA: 0s - loss: 0.0769
# Epoch 8: val_loss improved from 0.00722 to 0.00334, saving model to ./result_model.h5
# 76/76 [==============================] - 213s 3s/step - loss: 0.0769 - val_loss: 0.0033
# Epoch 9/10
# 76/76 [==============================] - ETA: 0s - loss: 0.0589
# Epoch 9: val_loss improved from 0.00334 to 0.00224, saving model to ./result_model.h5
# 76/76 [==============================] - 215s 3s/step - loss: 0.0589 - val_loss: 0.0022
# Epoch 10/10
# 76/76 [==============================] - ETA: 0s - loss: 0.0453
# Epoch 10: val_loss did not improve from 0.00224
# 76/76 [==============================] - 212s 3s/step - loss: 0.0453 - val_loss: 0.0036

# %%
plt.figure(figsize = (20, 5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train_loss', 'validation_loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.title('Losses vs Epochs')
plt.show()

# %%
from keras.models import load_model
model = load_model('./result_model.h5')

# %% [markdown]
# # Prediction

# %%
pred = model.predict(X_test)
# Out:
# 33/33 [==============================] - 26s 695ms/step

# %%
print(pred.shape)
# Out:
# (1043, 3)

# %% [markdown]
# # Performance Metrics
# #### Mean Squared Error
# Sum of squares of differences between actual value and predicted value, divided by the total number of samples. This is an **absolute measure**.
# #### R-squared score
# Basically this metric evaluates how well the model performs compared to predicting mean for every sample. This is a **relative measure**.

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('mean squared error : ' + str(mean_squared_error(y_test, pred)))
print('r2_score : ' + str(r2_score(y_test, pred)))
# Out:
# mean squared error : 0.0022423856949075616
# r2_score : 0.960920311003087

# %% [markdown]
# # Plot the Prediction and Test value

# %%
plt.figure(figsize = (20,15))

plt.subplot(3,1,1)
plt.plot(y_test[:50,0])
plt.plot(pred[:50,0])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Apple', fontsize = 15)


plt.subplot(3,1,2)
plt.plot(y_test[:50,1])
plt.plot(pred[:50,1])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Amazon',fontsize = 15)


plt.subplot(3,1,3)
plt.plot(y_test[:50,2])
plt.plot(pred[:50,2])
plt.xlabel('Period')
plt.ylabel('Closing Prices')
plt.legend(['testing price','predicted price'])
plt.title('Comparison in closing prices for Google',fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Comparison in closing prices for Google')

# %% [markdown]
# # Transfer learning

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('AAPL.csv')

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-30  42.607498  43.035000  42.110001  42.962502  40.853031
# 1  2017-12-01  42.487499  42.917500  42.125000  42.762501  40.662849
# 2  2017-12-04  43.119999  43.154999  42.407501  42.450001  40.365692
# 3  2017-12-05  42.264999  42.880001  42.099998  42.410000  40.327660
# 4  2017-12-06  41.875000  42.549999  41.615002  42.252499  40.177902
#
#       Volume
# 0  166108800
# 1  159037200
# 2  130169600
# 3  109400800
# 4  114240000

# %% [markdown]
# # Taking stock price data of Google

# %%
#df = df[df['symbol'] == 'GOOGL'].reset_index(drop = True)

# %%
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-30  42.607498  43.035000  42.110001  42.962502  40.853031
# 1  2017-12-01  42.487499  42.917500  42.125000  42.762501  40.662849
# 2  2017-12-04  43.119999  43.154999  42.407501  42.450001  40.365692
# 3  2017-12-05  42.264999  42.880001  42.099998  42.410000  40.327660
# 4  2017-12-06  41.875000  42.549999  41.615002  42.252499  40.177902
#
#       Volume
# 0  166108800
# 1  159037200
# 2  130169600
# 3  109400800
# 4  114240000

# %%
#df = df.drop(['symbol'], axis = 1)

# %%
print('Starting date : ' + str(df['Date'].min()))
print('Lasting date  : ' + str(df['Date'].max()))
# Out:
# Starting date : 2017-11-30
# Lasting date  : 2022-11-29

# %% [markdown]
# So the we have data from **04th January, 2010 to 30th December, 2016**.

# %%
print('Number of missing values : ' + str(df.isna().sum().sum()))
print(df.shape)
# Out:
# Number of missing values : 0
# (1258, 7)

# %% [markdown]
# It has already been observed that features **open, close, low and high** are highly correlated, so we must drop two of them (**low and high**) and **date** column. The other feature will be **volume traded**.

# %%
from tabulate import tabulate

# %%
info = [[col, df[col].count(), df[col].max(), df[col].min()] for col in df.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Maximum', 'Minimum'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count | Maximum    | Minimum    |
# |-----------+---------+------------+------------|
# | Date      |    1258 | 2022-11-29 | 2017-11-30 |
# | Open      |    1258 | 182.630005 | 35.994999  |
# | High      |    1258 | 182.940002 | 36.43      |
# | Low       |    1258 | 179.119995 | 35.5       |
# | Close     |    1258 | 182.009995 | 35.547501  |
# | Adj Close |    1258 | 180.959747 | 34.309586  |
# | Volume    |    1258 | 426510000  | 35195900   |

# %%
X = np.array(df.drop(['Date', 'High', 'Low', 'Close', 'Adj Close'], axis = 1))
y = np.array(df['Close'])

# %%
print(X.shape)
print(y.shape)
# Out:
# (1258, 2)
# (1258,)

# %% [markdown]
# # Scale

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = MinMaxScaler().fit_transform(X)

# %%
t = np.reshape(y, (len(y),1))
t = MinMaxScaler().fit_transform(t)
y = t.reshape(-1)

# %%
print(X.max())
print(X.min())
# Out:
# 1.0
# 0.0

# %%
print(y.max())
print(y.min())
# Out:
# 1.0000000000000002
# 0.0

# %% [markdown]
# # Convert to time series data

# %%
length = 300

X_res = []
y_res = []

for i in range(length , len(X)) :
    X_res.append(X[i-length:i])
    y_res.append(y[i])

X_res = np.array(X_res)
y_res = np.array(y_res)

# %%
print(X_res.shape)
print(y_res.shape)
# Out:
# (958, 300, 2)
# (958,)

# %% [markdown]
# # Train/test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (766, 300, 2)
# (766,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (192, 300, 2)
# (192,)

# %% [markdown]
# # Build the model

# %%
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Bidirectional
from keras.layers import BatchNormalization

# %%
'''
def lstm_layer (hiddenx) :
    
    model = Sequential()
    
    model.add(Bidirectional(LSTM(hiddenx, activation = 'tanh', return_sequences = True)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    return model
'''

def mod (hidden1, hidden2, hidden3) :
    
    model = Sequential()
    
    # Input layer
    model.add(Input((length, 2,)))
    
    # lstm layer
    model.add(lstm_layer(hidden1))
    model.add(lstm_layer(hidden2))
    model.add(Bidirectional(LSTM(hidden3, activation = 'tanh', return_sequences = False)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    
    # output layer
    model.add(Dense(1, activation = 'linear'))
    
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')
    
    return model

# %%
model = mod(128, 64, 64)
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_7 (Sequential)   (None, 300, 256)          135168
#
#  sequential_8 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_8 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 398,465
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# # Model training

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./transfer_model.h5', monitor = 'val_loss', verbose = 1, save_best_only = True)

# %%
history = model.fit(X_train, y_train, epochs = 10, batch_size = 32, callbacks = [checkp], validation_data = (X_test, y_test))
# Out:
# Epoch 1/10
# 24/24 [==============================] - ETA: 0s - loss: 1.1859
# Epoch 1: val_loss improved from inf to 0.16583, saving model to ./transfer_model.h5
# 24/24 [==============================] - 66s 2s/step - loss: 1.1859 - val_loss: 0.1658
# Epoch 2/10
# 24/24 [==============================] - ETA: 0s - loss: 0.5959
# Epoch 2: val_loss improved from 0.16583 to 0.14303, saving model to ./transfer_model.h5
# 24/24 [==============================] - 50s 2s/step - loss: 0.5959 - val_loss: 0.1430
# Epoch 3/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4995
# Epoch 3: val_loss improved from 0.14303 to 0.13325, saving model to ./transfer_model.h5
# 24/24 [==============================] - 48s 2s/step - loss: 0.4995 - val_loss: 0.1333
# Epoch 4/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4402
# Epoch 4: val_loss did not improve from 0.13325
# 24/24 [==============================] - 59s 2s/step - loss: 0.4402 - val_loss: 0.1399
# Epoch 5/10
# 24/24 [==============================] - ETA: 0s - loss: 0.4085
# Epoch 5: val_loss improved from 0.13325 to 0.10887, saving model to ./transfer_model.h5
# 24/24 [==============================] - 50s 2s/step - loss: 0.4085 - val_loss: 0.1089
# Epoch 6/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3870
# Epoch 6: val_loss improved from 0.10887 to 0.10200, saving model to ./transfer_model.h5
# 24/24 [==============================] - 51s 2s/step - loss: 0.3870 - val_loss: 0.1020
# Epoch 7/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3403
# Epoch 7: val_loss did not improve from 0.10200
# 24/24 [==============================] - 48s 2s/step - loss: 0.3403 - val_loss: 0.1093
# Epoch 8/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3175
# Epoch 8: val_loss did not improve from 0.10200
# 24/24 [==============================] - 49s 2s/step - loss: 0.3175 - val_loss: 0.1742
# Epoch 9/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2857
# Epoch 9: val_loss did not improve from 0.10200
# 24/24 [==============================] - 49s 2s/step - loss: 0.2857 - val_loss: 0.1404
# Epoch 10/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2619
# Epoch 10: val_loss did not improve from 0.10200
# 24/24 [==============================] - 49s 2s/step - loss: 0.2619 - val_loss: 0.1416

# %%
plt.figure(figsize = (20,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training loss', 'Validation loss'])
plt.xlabel('Epochs')
plt.ylabel('Losses')
plt.title('Losses vs Epochs')
# Out:
# Text(0.5, 1.0, 'Losses vs Epochs')

# %% [markdown]
# # Prediction on test data

# %%
from keras.models import load_model
model = load_model('./transfer_model.h5')

# %%
pred = model.predict(X_test)
# Out:
# 6/6 [==============================] - 6s 500ms/step

# %%
print(pred.shape)
# Out:
# (192, 1)

# %%
pred = pred.reshape(-1)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
print('Mean squared error : ' + str(mean_squared_error(y_test, pred)))
print('r2_score : ' + str(r2_score(y_test, pred)))
# Out:
# Mean squared error : 0.10200449352690637
# r2_score : -0.2216571032785586

# %%
plt.figure(figsize = (20,5))

plt.plot(y_test[:100])
plt.plot(pred[:100])
plt.legend(['Testing values', 'predicted values'])
plt.xlabel('Time Period')
plt.ylabel('Closing prices')
plt.title('Comparison b/w predicted and real closing prices (Google)')
# Out:
# Text(0.5, 1.0, 'Comparison b/w predicted and real closing prices (Google)')

# %% [markdown]
# # Now let's evaluate model's performance on stock data of Amazon and Apple.

# %%
apple = pandas.read_csv('MSFT.csv')
amazn = pandas.read_csv('AMZN.csv')

# %%
#apple = df[df['symbol'] == 'MSFT'].reset_index(drop = True)
#amazn = df1[df1['symbol'] == 'AMZN'].reset_index(drop = True)

# %%
apple.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2017-11-27  83.309998  83.980003  83.300003  83.870003  78.981628  18265200
# 1  2017-11-28  84.070000  85.059998  84.019997  84.879997  79.932755  21926000
# 2  2017-11-29  84.709999  84.919998  83.180000  83.339996  78.482498  27381100
# 3  2017-11-30  83.510002  84.519997  83.339996  84.169998  79.264137  33054600
# 4  2017-12-01  83.599998  84.809998  83.220001  84.260002  79.348877  29532100

# %%
amazn.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2017-11-27  60.132999  60.670502  59.557499  59.791500  59.791500
# 1  2017-11-28  60.243999  60.266998  59.425999  59.680000  59.680000
# 2  2017-11-29  59.740002  59.740002  57.259499  58.063499  58.063499
# 3  2017-11-30  58.355000  58.928501  58.000000  58.837502  58.837502
# 4  2017-12-01  58.602501  58.982498  57.599998  58.117500  58.117500
#
#       Volume
# 0  134880000
# 1   91188000
# 2  185150000
# 3   90184000
# 4   82142000

# %%
print('Apple,')
print('Number of missing values : ' + str(apple.isna().sum().sum()))
print(apple.shape)

print('Amazon')
print('Number of missing values : ' + str(amazn.isna().sum().sum()))
print(amazn.shape)
# Out:
# Apple,
# Number of missing values : 0
# (1259, 7)
# Amazon
# Number of missing values : 0
# (1259, 7)

# %%
apple = apple.drop(['Date'], axis = 1)
amazn = amazn.drop(['Date'], axis = 1)

# %%
info = [[col, apple[col].count(), apple[col].max(), apple[col].min()] for col in apple.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Max', 'Min'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count |           Max |         Min |
# |-----------+---------+---------------+-------------|
# | Open      |    1259 | 344.62        | 81.34       |
# | High      |    1259 | 349.67        | 82.68       |
# | Low       |    1259 | 342.2         | 80.7        |
# | Close     |    1259 | 343.11        | 81.08       |
# | Adj Close |    1259 | 339.925       | 76.3542     |
# | Volume    |    1259 |   1.11242e+08 |  8.9892e+06 |

# %%
info = [[col, amazn[col].count(), amazn[col].max(), amazn[col].min()] for col in amazn.columns]
print(tabulate(info, headers = ['Feature', 'Count', 'Max', 'Min'], tablefmt = 'orgtbl'))
# Out:
# | Feature   |   Count |           Max |         Min |
# |-----------+---------+---------------+-------------|
# | Open      |    1259 | 187.2         | 56.413      |
# | High      |    1259 | 188.654       | 57.7945     |
# | Low       |    1259 | 184.839       | 56.237      |
# | Close     |    1259 | 186.57        | 56.6975     |
# | Adj Close |    1259 | 186.57        | 56.6975     |
# | Volume    |    1259 |   3.11346e+08 |  1.7626e+07 |

# %% [markdown]
# # Create arrays
# Only use **open price and volume traded**, as other features are correlated with closing price.

# %%
X_apple = np.array(apple.drop(['Close', 'Low', 'High','Adj Close'], axis = 1))
y_apple = np.array(apple['Close'])

X_amazn = np.array(amazn.drop(['Close', 'Low', 'High', 'Adj Close'], axis = 1))
y_amazn = np.array(amazn['Close'])

# %%
print(X_apple.shape)
print(y_apple.shape)
# Out:
# (1259, 2)
# (1259,)

# %%
print(X_amazn.shape)
print(y_amazn.shape)
# Out:
# (1259, 2)
# (1259,)

# %% [markdown]
# # Scale

# %%
X_apple = MinMaxScaler().fit_transform(X_apple)
X_amazn = MinMaxScaler().fit_transform(X_amazn)

# %%
t = np.reshape(y_apple, (len(y_apple),1))
t = MinMaxScaler().fit_transform(t)
y_apple = t.reshape(-1)

# %%
t = np.reshape(y_amazn, (len(y_amazn),1))
t = MinMaxScaler().fit_transform(t)
y_amazn = t.reshape(-1)

# %%
print(X_apple.max())
print(X_apple.min())
# Out:
# 1.0
# 0.0

# %%
print(y_apple.max())
print(y_apple.min())
# Out:
# 1.0
# 0.0

# %%
print(X_amazn.max())
print(X_amazn.min())
# Out:
# 1.0000000000000002
# 0.0

# %%
print(y_amazn.max())
print(y_amazn.min())
# Out:
# 0.9999999999999999
# 0.0

# %% [markdown]
# # Verify the shapes

# %%
print(X_apple.shape)
print(y_apple.shape)
# Out:
# (1259, 2)
# (1259,)

# %%
print(X_amazn.shape)
print(y_amazn.shape)
# Out:
# (1259, 2)
# (1259,)

# %% [markdown]
# # Create timesteps of size 300

# %%
length = 300

X_res_apple = []
y_res_apple = []

X_res_amazn = []
y_res_amazn = []

# %%
for i in range(length, len(X_apple)) :
    
    X_res_apple.append(X_apple[i-length:i])            # take 300 prior data for apple stock
    y_res_apple.append(y_apple[i])                     # next day closing price
    
    X_res_amazn.append(X_amazn[i-length:i])            # take 300 prior data for Amazonstock
    y_res_amazn.append(y_amazn[i])                     # next day closing price

X_res_apple, y_res_apple = np.array(X_res_apple), np.array(y_res_apple)
X_res_amazn, y_res_amazn = np.array(X_res_amazn), np.array(y_res_amazn)

# %%
print(X_res_apple.shape)
print(y_res_apple.shape)
# Out:
# (959, 300, 2)
# (959,)

# %%
print(X_res_amazn.shape)
print(y_res_amazn.shape)
# Out:
# (959, 300, 2)
# (959,)

# %%
from sklearn.utils import shuffle

# %%
X_res_apple, y_res_apple = shuffle(X_res_apple, y_res_apple, random_state = 1)
X_res_amazn, y_res_amazn = shuffle(X_res_amazn, y_res_amazn, random_state = 1)

# %% [markdown]
# # Predict for apple stock data

# %%
from keras.models import load_model
model = load_model('./transfer_model.h5')

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = False

# %%
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_7 (Sequential)   (None, 300, 256)          135168
#
#  sequential_8 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_8 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 129
# Non-trainable params: 399,360
# _________________________________________________________________
# None

# %%
X_apple_train, X_apple_test, y_apple_train, y_apple_test = train_test_split(X_res_apple, y_res_apple, test_size = 0.2, random_state = 1)

# %%
print(X_apple_train.shape)
print(y_apple_train.shape)
# Out:
# (767, 300, 2)
# (767,)

# %%
print(X_apple_test.shape)
print(y_apple_test.shape)
# Out:
# (192, 300, 2)
# (192,)

# %% [markdown]
# ### Training

# %%
checkp = ModelCheckpoint('./best_apple_model.h5', save_best_only = True, monitor = 'val_loss', verbose = 1)

# %%
history = model.fit(X_apple_train, y_apple_train, epochs = 10, batch_size = 32, validation_data = (X_apple_test, y_apple_test), callbacks = [checkp])
# Out:
# Epoch 1/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3438
# Epoch 1: val_loss improved from inf to 0.13001, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 58s 2s/step - loss: 0.3438 - val_loss: 0.1300
# Epoch 2/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3296
# Epoch 2: val_loss improved from 0.13001 to 0.10915, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 47s 2s/step - loss: 0.3296 - val_loss: 0.1091
# Epoch 3/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2859
# Epoch 3: val_loss did not improve from 0.10915
# 24/24 [==============================] - 47s 2s/step - loss: 0.2859 - val_loss: 0.1438
# Epoch 4/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2837
# Epoch 4: val_loss improved from 0.10915 to 0.06876, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 48s 2s/step - loss: 0.2837 - val_loss: 0.0688
# Epoch 5/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2451
# Epoch 5: val_loss did not improve from 0.06876
# 24/24 [==============================] - 50s 2s/step - loss: 0.2451 - val_loss: 0.1045
# Epoch 6/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2309
# Epoch 6: val_loss improved from 0.06876 to 0.04887, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 49s 2s/step - loss: 0.2309 - val_loss: 0.0489
# Epoch 7/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2044
# Epoch 7: val_loss improved from 0.04887 to 0.02155, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 49s 2s/step - loss: 0.2044 - val_loss: 0.0216
# Epoch 8/10
# 24/24 [==============================] - ETA: 0s - loss: 0.1991
# Epoch 8: val_loss improved from 0.02155 to 0.01347, saving model to ./best_apple_model.h5
# 24/24 [==============================] - 49s 2s/step - loss: 0.1991 - val_loss: 0.0135
# Epoch 9/10
# 24/24 [==============================] - ETA: 0s - loss: 0.1971
# Epoch 9: val_loss did not improve from 0.01347
# 24/24 [==============================] - 49s 2s/step - loss: 0.1971 - val_loss: 0.0156
# Epoch 10/10
# 24/24 [==============================] - ETA: 0s - loss: 0.1647
# Epoch 10: val_loss did not improve from 0.01347
# 24/24 [==============================] - 49s 2s/step - loss: 0.1647 - val_loss: 0.0230

# %%
model = load_model('./best_apple_model.h5')
y_apple_pred = model.predict(X_apple_test)
# Out:
# 6/6 [==============================] - 6s 507ms/step

# %%
print(y_apple_pred.shape)
# Out:
# (192, 1)

# %%
y_apple_pred = y_apple_pred.reshape(-1)

# %%
print('Apple,')
print('Mean squared error : ' + str(mean_squared_error(y_apple_test, y_apple_pred)))
print('r2 score : ' + str(r2_score(y_apple_test, y_apple_pred)))
# Out:
# Apple,
# Mean squared error : 0.013468257358101298
# r2 score : 0.7768458914217302

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize = (20,5))

plt.plot(y_apple_test[100:200])
plt.plot(y_apple_pred[100:200])

plt.xlabel('Time period')
plt.ylabel('Closing prices')
plt.legend(['Actual Price', 'Predicted price'])
plt.title('Closing price comparison for Apple dataset', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Closing price comparison for Apple dataset')

# %% [markdown]
# # Predict for amazon stock data

# %%
model = load_model('./transfer_model.h5')

# %%
for i, layer in enumerate(model.layers) :
    if i < 5 :
        layer.trainable = False

# %%
print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_7 (Sequential)   (None, 300, 256)          135168
#
#  sequential_8 (Sequential)   (None, 300, 128)          164864
#
#  bidirectional_8 (Bidirectio  (None, 128)              98816
#  nal)
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 399,489
# Trainable params: 129
# Non-trainable params: 399,360
# _________________________________________________________________
# None

# %%
X_amazn_train,  X_amazn_test, y_amazn_train, y_amazn_test = train_test_split(X_res_amazn, y_res_amazn, test_size = 0.2, random_state = 1)

# %%
print(X_amazn_train.shape)
print(y_amazn_train.shape)
# Out:
# (767, 300, 2)
# (767,)

# %%
print(X_amazn_test.shape)
print(y_amazn_test.shape)
# Out:
# (192, 300, 2)
# (192,)

# %% [markdown]
# ### Train on the last layer

# %%
from keras.callbacks import ModelCheckpoint
checkp = ModelCheckpoint('./best_amazn_model.h5', monitor = 'val_loss', save_best_only = True, verbose = 1)

# %%
history = model.fit(X_amazn_train, y_amazn_train, epochs = 10, batch_size = 32, validation_data = (X_amazn_test, y_amazn_test), callbacks = [checkp])
# Out:
# Epoch 1/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3231
# Epoch 1: val_loss improved from inf to 0.19044, saving model to ./best_amazn_model.h5
# 24/24 [==============================] - 60s 2s/step - loss: 0.3231 - val_loss: 0.1904
# Epoch 2/10
# 24/24 [==============================] - ETA: 0s - loss: 0.3200
# Epoch 2: val_loss improved from 0.19044 to 0.10125, saving model to ./best_amazn_model.h5
# 24/24 [==============================] - 47s 2s/step - loss: 0.3200 - val_loss: 0.1012
# Epoch 3/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2807
# Epoch 3: val_loss did not improve from 0.10125
# 24/24 [==============================] - 47s 2s/step - loss: 0.2807 - val_loss: 0.1380
# Epoch 4/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2660
# Epoch 4: val_loss improved from 0.10125 to 0.06299, saving model to ./best_amazn_model.h5
# 24/24 [==============================] - 47s 2s/step - loss: 0.2660 - val_loss: 0.0630
# Epoch 5/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2676
# Epoch 5: val_loss improved from 0.06299 to 0.04885, saving model to ./best_amazn_model.h5
# 24/24 [==============================] - 47s 2s/step - loss: 0.2676 - val_loss: 0.0488
# Epoch 6/10
# 24/24 [==============================] - ETA: 0s - loss: 0.2293
# Epoch 6: val_loss did not improve from 0.04885
# 24/24 [==============================] - 48s 2s/step - loss: 0.2293 - val_loss: 0.0520
# Epoch 7/10
#  8/24 [=========>....................] - ETA: 29s - loss: 0.2198

# %% [markdown]
# ### Use the 'best_amazn_model.h5' for prediction

# %%
model = load_model('./best_amazn_model.h5')

# %%
y_amazn_pred = model.predict(X_amazn_test)

# %%
print(y_amazn_pred.shape)

# %%
y_amazn_pred = y_amazn_pred.reshape(-1)

# %%
print('Mean_sqaured_error : ' + str(mean_squared_error(y_amazn_test, y_amazn_pred)))
print('r2_score : ' + str(r2_score(y_amazn_test, y_amazn_pred)))

# %% [markdown]
# ### Visualization

# %%
plt.figure(figsize = (20,5))

plt.plot(y_amazn_test[100:200])
plt.plot(y_amazn_pred[100:200])

plt.xlabel('Time period')
plt.ylabel('Closing prices')
plt.legend(['Actual Price', 'Predicted price'])
plt.title('Closing price comparison for Amazon dataset', fontsize = 15)

# %%
# import the module
from sklearn.metrics import mean_absolute_error as mae
  
# list of integers of actual and calculated
  
# calculate MAE
error = mae(y_amazn_test, y_amazn_pred)
  
# display
print("Mean absolute error : " + str(error))
# Out:
# Mean absolute error : 0.103761491717884
